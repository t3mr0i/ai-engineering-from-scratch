# %% [markdown]
# # 06-knn-and-distances
# This notebook executes the same deterministic fixture as the canonical demo.

# %%
from pathlib import Path
import sys
candidates = [Path.cwd() / "phases/02-ml-fundamentals/06-knn-and-distances/code", Path.cwd().parents[1] / "code", Path.cwd() / "code"]
code_dir = next(path for path in candidates if (path / ("knn.py")).exists())
sys.path.insert(0, str(code_dir))
from knn import *

# %%
model = KNN(k=3).fit([[0], [1], [10]], ['near', 'near', 'far'])
print(model.predict([[0.5]]))

# %%
print(l1_distance([1, 2], [4, 6]), l2_distance([1, 2], [4, 6]), KDTree([[0], [2]]).query([0.2], 1))
