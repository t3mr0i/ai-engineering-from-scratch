# %% [markdown]
# # Git & Collaboration Notebook
#
# > Version control is not optional. Every experiment, every model, every lesson you build here gets tracked.

# %% [markdown]
# ## Build It: Step 1 - Configure git

# %%
# !git config --global user.name "Your Name"
# !git config --global user.email "you@example.com"

# %% [markdown]
# ## Exercises

# %%
print("Exercise 1: Clone repo, create branch, make file, commit, push")
print("Exercise 2: Create .gitignore for model files")
