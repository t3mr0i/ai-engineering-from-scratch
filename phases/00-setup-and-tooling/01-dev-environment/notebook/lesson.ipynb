# %% [markdown]
# # Dev Environment Setup Notebook
#
# > Make the toolchain observable before the first model is imported.

# %% [markdown]
# ## Build It: Step 1 - System Foundation

# %%
# !echo "Step 1: Check system and install basics. (Commands in terminal)"

# %% [markdown]
# ### Step 2: Python with uv

# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh!uv python install 3.12!uv venv!source .venv/bin/activate!uv pip install numpy

# %%
import sys
print(f"Python {sys.version}")
import numpy as np
print(f"NumPy {np.__version__}")
a = np.array([1, 2, 3])
print(f"Vector: {a}, dot product: {np.dot(a, a)}")

# %% [markdown]
# ## Exercises

# %%
print("Exercise 1: Run verification")print("Exercise 2: Create a disposable venv")print("Exercise 3: Run the Rust, Python, and Node probes")
