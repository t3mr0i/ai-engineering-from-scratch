# %% [markdown]
# # Dev Environment Setup Notebook
#
# > Your tools shape your thinking. Set them up once, set them up right.

# %% [markdown]
# ## Build It: Step 1 - System Foundation

# %%
# !echo "Step 1: Check system and install basics. (Commands in terminal)"

# %% [markdown]
# ### Step 2: Python with uv

# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh!uv python install 3.12!uv venv!source .venv/bin/activate!uv pip install numpy matplotlib jupyter

# %%
import sys
print(f"Python {sys.version}")
import numpy as np
print(f"NumPy {np.__version__}")
a = np.array([1, 2, 3])
print(f"Vector: {a}, dot product: {np.dot(a, a)}")

# %% [markdown]
# ## Exercises

# %%
print("Exercise 1: Run verification")print("Exercise 2: Create venv and install PyTorch")print("Exercise 3: Hello world in multiple languages")
