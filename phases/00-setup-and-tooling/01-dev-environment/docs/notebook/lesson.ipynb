# %% [markdown]
# # Lesson Notebook
#
# > Hands-on Build It and Exercises.

# %% [markdown]
# ## Build It

# %%
print('Build It code cells go here — extract from docs/en.md')

# %% [markdown]
# ## Exercises

# %%
print('Exercise 1...')
