# %% [markdown]
# # Python Environments
#
# > Verify the interpreter before adding an allowlisted package.

# %% [markdown]
# ## Build It: read-only report

# %%
from main import environment_report
import json
print(json.dumps(environment_report(), indent=2))

# %% [markdown]
# `isolated` is true when `sys.prefix` differs from `sys.base_prefix`. The report does not create a venv or install anything.

# %% [markdown]
# ## Use It: disposable environment

# %%
# Run in a shell outside the tracked lesson when mutation is intentional:
# python3 -m venv /tmp/phase00-python-env
# /tmp/phase00-python-env/bin/python code/main.py

# %% [markdown]
# `code/env_setup.sh` is the optional provisioning path. It creates a venv and installs only NumPy; PyTorch is reported only when already available. Keep the repository's stdlib-first contract separate from later framework environments.
